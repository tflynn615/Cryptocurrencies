# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Deliverable 1: Preprocessing the Data for PCA

# %%
# Load the crypto_data.csv dataset.
df_crypto = pd.read_csv("crypto_data.csv", index_col="Unnamed: 0")
df_crypto.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep all the cryptocurrencies that are being traded.
new_df_crypto = df_crypto[df_crypto['IsTrading'] == True]
new_df_crypto.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep all the cryptocurrencies that have a working algorithm
new_df_crypto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1144 entries, 42 to XBC
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CoinName         1144 non-null   object
#  1   Algorithm        1144 non-null   object
#  2   IsTrading        1144 non-null   bool
#  3   ProofType        1144 non-null   object
#  4   TotalCoinsMined  685 non-null    float64
#  5   TotalCoinSupply  1144 non-null   object
# dtypes: bool(1), float64(1), object(4)
# memory usage: 54.7+ KB

# %%
# Remove the "IsTrading" column. 
new_df_crypto = new_df_crypto.drop(["IsTrading"], axis='columns')
new_df_crypto.head()
# Out:
#       CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       PoW              NaN          611000
# 808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Remove rows that have at least 1 null value.
crypto_df = new_df_crypto.dropna()
print(crypto_df.count())
crypto_df.head()
# Out:
# CoinName           685
# Algorithm          685
# ProofType          685
# TotalCoinsMined    685
# TotalCoinSupply    685
# dtype: int64
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
# Keep the rows where coins are mined.
crypto_df = crypto_df[crypto_df['TotalCoinsMined'] > 0]
print(crypto_df.count())
crypto_df.head()
# Out:
# CoinName           532
# Algorithm          532
# ProofType          532
# TotalCoinsMined    532
# TotalCoinSupply    532
# dtype: int64
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
crypto_names = pd.DataFrame(crypto_df['CoinName'].unique())
crypto_names
# Out:
#                0
# 0        42 Coin
# 1        404Coin
# 2      EliteCoin
# 3        Bitcoin
# 4       Ethereum
# ..           ...
# 526       ZEPHYR
# 527      Gapcoin
# 528       Beldex
# 529      Horizen
# 530  BitcoinPlus
#
# [531 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm.
crypto_df = crypto_df.drop(['CoinName'], axis='columns')
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(crypto_df)
X
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 42       4.199995e+01                                 0              0
# 404      1.055185e+09                                 0              0
# 1337     2.927942e+10                                 0              0
# BTC      1.792718e+07                                 0              0
# ETH      1.076842e+08                                 0              0
# ...               ...                               ...            ...
# ZEPH     2.000000e+09                                 0              0
# GAP      1.493105e+07                                 0              0
# BDX      9.802226e+08                                 0              0
# ZEN      7.296538e+06                                 0              0
# XBC      1.283270e+05                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                    0                   0                0
# 404                   0                   0                0
# 1337                  0                   0                0
# BTC                   0                   0                0
# ETH                   0                   0                0
# ...                 ...                 ...              ...
# ZEPH                  0                   0                0
# GAP                   0                   0                0
# BDX                   0                   0                0
# ZEN                   0                   0                0
# XBC                   0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  \
# 42                    0                  0              0
# 404                   0                  0              0
# 1337                  0                  0              0
# BTC                   0                  0              0
# ETH                   0                  0              0
# ...                 ...                ...            ...
# ZEPH                  0                  0              0
# GAP                   0                  0              0
# BDX                   0                  0              0
# ZEN                   0                  0              0
# XBC                   0                  0              0
#
#       Algorithm_Cloverhash  ...  TotalCoinSupply_91388946  \
# 42                       0  ...                         0
# 404                      0  ...                         0
# 1337                     0  ...                         0
# BTC                      0  ...                         0
# ETH                      0  ...                         0
# ...                    ...  ...                       ...
# ZEPH                     0  ...                         0
# GAP                      0  ...                         0
# BDX                      0  ...                         0
# ZEN                      0  ...                         0
# XBC                      0  ...                         0
#
#       TotalCoinSupply_92000000000  TotalCoinSupply_9354000  \
# 42                              0                        0
# 404                             0                        0
# 1337                            0                        0
# BTC                             0                        0
# ETH                             0                        0
# ...                           ...                      ...
# ZEPH                            0                        0
# GAP                             0                        0
# BDX                             0                        0
# ZEN                             0                        0
# XBC                             0                        0
#
#       TotalCoinSupply_9507271  TotalCoinSupply_9736000  \
# 42                          0                        0
# 404                         0                        0
# 1337                        0                        0
# BTC                         0                        0
# ETH                         0                        0
# ...                       ...                      ...
# ZEPH                        0                        0
# GAP                         0                        0
# BDX                         0                        0
# ZEN                         0                        0
# XBC                         0                        0
#
#       TotalCoinSupply_98000000  TotalCoinSupply_98100000000  \
# 42                           0                            0
# 404                          0                            0
# 1337                         0                            0
# BTC                          0                            0
# ETH                          0                            0
# ...                        ...                          ...
# ZEPH                         0                            0
# GAP                          0                            0
# BDX                          0                            0
# ZEN                          0                            0
# XBC                          0                            0
#
#       TotalCoinSupply_990000000000  TotalCoinSupply_999481516  \
# 42                               0                          0
# 404                              0                          0
# 1337                             0                          0
# BTC                              0                          0
# ETH                              0                          0
# ...                            ...                        ...
# ZEPH                             0                          0
# GAP                              0                          0
# BDX                              0                          0
# ZEN                              0                          0
# XBC                              0                          0
#
#       TotalCoinSupply_9999999
# 42                          0
# 404                         0
# 1337                        0
# BTC                         0
# ETH                         0
# ...                       ...
# ZEPH                        0
# GAP                         0
# BDX                         0
# ZEN                         0
# XBC                         0
#
# [532 rows x 377 columns]

# %%
# Standardize the data with StandardScaler().
crypto_scaled = StandardScaler().fit_transform(X)
print(crypto_scaled[:5])
# Out:
# [[-0.11710817 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.09396955 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [ 0.52494561 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11671506 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11474682 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]]

# %% [markdown]
# ### Deliverable 2: Reducing Data Dimensions Using PCA

# %%
# Using PCA to reduce dimension to three principal components.
pca = PCA(n_components = 3)
crypto_pca = pca.fit_transform(crypto_scaled)

crypto_pca
# Out:
# array([[-0.18585961, -0.10546848, -0.13273079],
#        [-0.16520887, -0.10993537, -0.13248871],
#        [ 0.18424726, -0.03005651, -0.10396522],
#        ...,
#        [-0.07322863, -0.40319203,  0.01126788],
#        [-0.3037992 , -0.25426214,  0.11153809],
#        [-0.14407744,  0.00140146, -0.08591764]])

# %%
# Create a DataFrame with the three principal components.
pca_df = pd.DataFrame(data=crypto_pca, columns=["PC 1","PC 2","PC 3"], index=X.index) 

pca_df
# Out:
#           PC 1      PC 2      PC 3
# 42   -0.185860 -0.105468 -0.132731
# 404  -0.165209 -0.109935 -0.132489
# 1337  0.184247 -0.030057 -0.103965
# BTC  -0.283206 -0.210584 -0.012117
# ETH  -0.140214 -0.282832 -0.099295
# ...        ...       ...       ...
# ZEPH  2.425162 -0.478924  0.374492
# GAP  -0.173449 -0.161553 -0.108587
# BDX  -0.073229 -0.403192  0.011268
# ZEN  -0.303799 -0.254262  0.111538
# XBC  -0.144077  0.001401 -0.085918
#
# [532 rows x 3 columns]

# %% [markdown]
# ### Deliverable 3: Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
# Create an elbow curve to find the best value for K.
# YOUR CODE HERE

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model.
# YOUR CODE HERE

# Fit the model
# YOUR CODE HERE

# Predict clusters
# YOUR CODE HERE

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
# YOUR CODE HERE

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 
# YOUR CODE HERE

#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
# YOUR CODE HERE

# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)

# %% [markdown]
# ### Deliverable 4: Visualizing Cryptocurrencies Results
#
# #### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
# YOUR CODE HERE

# %%
# Create a table with tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Print the total number of tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# YOUR CODE HERE

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
# YOUR CODE HERE

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
# YOUR CODE HERE

plot_df.head(10)

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
# YOUR CODE HERE
